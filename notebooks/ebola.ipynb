# %% [markdown]
# # Ebola Outbreak 2014

# %% [markdown]
# ## Data retrieval

# %%
df = pd.DataFrame.from_csv('https://raw.githubusercontent.com/cmrivers/ebola/master/country_timeseries.csv',
                 index_col=0)
df = df.sort_index()
df = df.fillna(method='ffill')

# %% [markdown]
# ## Cases per country

# %%
titles = [k for k in df.columns if 'cases'  in k.lower()]
df.plot(y=titles, kind='area')
legend()

# %% [markdown]
# ## Deaths per Country

# %%
titles = [k for k in df.columns if 'Deaths' in k]
df.plot(y=titles,kind='area')
legend()

# %% [markdown]
# ## Total Deaths

# %%
df['total deaths'] = df[death_titles].sum(axis =1)
df.plot(y='total deaths', 
        title='Total Deaths in \n 2014 Ebola Outbreak')
ylabel('Total Deaths')

# %% [markdown]
# ## Exponential Fit

# %% [markdown]
# ### Plot Log(deaths) and exponential fit

# %%
import seaborn as sn
df['log total deaths'] = log10(df['total deaths'].values)
sn.lmplot('Day','log total deaths', df)

# %% [markdown]
# ### Fit statistics

# %%
import statsmodels.formula.api as sm

ols = sm.OLS(df['Day'].values, df['log total deaths'].values)
ols.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.845
# Method:                 Least Squares   F-statistic:                     411.1
# Date:                Wed, 01 Oct 2014   Prob (F-statistic):           6.12e-32
# Time:                        12:30:16   Log-Likelihood:                -384.83
# No. Observations:                  75   AIC:                             771.7
# Df Residuals:                      74   BIC:                             774.0
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            36.8045      1.815     20.275      0.000        33.188    40.421
# ==============================================================================
# Omnibus:                       59.911   Durbin-Watson:                   0.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                6.283
# Skew:                           0.063   Prob(JB):                       0.0432
# Kurtosis:                       1.588   Cond. No.                         1.00
# ==============================================================================
# """
